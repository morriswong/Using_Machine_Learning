# %% [markdown]
# # Billionaires.
#
# Found out an interesting [post](https://www.bloomberg.com/billionaires/) on Bloomberg listing 500 richest people on earth (publicly), so crawled down the data and did some plots.
#
# As of March 30, 2017

# %%
import pandas as pd

# %%
bil = pd.read_csv("Data/billionaires.csv", sep = ",")

# %%
print(bil.head())
# Out:
#    Rank             Name  Total_net_worth   Last_change    YTD_change  \
# 0     1       Bill Gates     8.600000e+10   -11400000.0  3.630000e+06
# 1     2       Jeff Bezos     7.560000e+10     1490000.0  1.020000e+10
# 2     3   Warren Buffett     7.490000e+10  -809000000.0  1.750000e+06
# 3     4   Amancio Ortega     7.420000e+10   121000000.0  2.100000e+09
# 4     5  Mark Zuckerberg     6.140000e+10   340000000.0  1.140000e+10
#
#          Country     Industry
# 0  United States   Technology
# 1  United States   Technology
# 2  United States  Diversified
# 3          Spain       Retail
# 4  United States   Technology

# %% [markdown]
# ### The total money of the Richest 500

# %%
total_net_worth = sum(bil["Total_net_worth"])

print("Total_net_worth:", total_net_worth)
print("Total_net_worth:", total_net_worth / 1e+12, "trillion")
print("Total_net_worth:", total_net_worth / 1e+9, "billion")
# Out:
# Total_net_worth: 4.7233e+12
# Total_net_worth: 4.7233 trillion
# Total_net_worth: 4723.3 billion

# %% [markdown]
# The total wealth of the world in 2015 was estimated to be **`$250.1`** trillion dollars by [Credit Suisse](https://publications.credit-suisse.com/tasks/render/file/?fileID=F2425415-DCA7-80B8-EAD989AF9341D47E) in their annual global wealth report

# %%
country_bil_count = pd.DataFrame(bil["Country"].value_counts())
industry_bil_count = pd.DataFrame(bil["Industry"].value_counts())

# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (16, 6)

country_bil_count.plot.bar()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (10, 4)

industry_bil_count.plot.bar()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# bil["Country"].value_counts()

# bil['Last_change'] = bil['Last_change'].astype(float)
Last_change_in_industries = bil[["Last_change", "Industry"]].groupby("Industry") \
                            .sum().reset_index().sort_values(["Industry", "Last_change"])

# Last_change_in_industries.reindex_axis(sorted(Last_change_in_industries.columns), axis=1)
sorted(Last_change_in_industries["Last_change"])
# Out:
# ['Industry', 'Last_change']

# %%
YTD_change_in_industries = bil[["YTD_change", "Industry"]].groupby("Industry").sum()
Last_change_in_country = bil[["Last_change", "Industry"]].groupby("Industry").sum()
YTD_change_in_country = bil[["YTD_change", "Industry"]].groupby("Industry").sum()

# %%
bil[["YTD_change", "Industry"]]
# Out:
#        YTD_change         Industry
# 0    3.630000e+06       Technology
# 1    1.020000e+10       Technology
# 2    1.750000e+06      Diversified
# 3    2.100000e+09           Retail
# 4    1.140000e+10       Technology
# 5    8.200000e+06      Diversified
# 6    2.290000e+06       Industrial
# 7    2.290000e+06       Industrial
# 8    5.450000e+06       Technology
# 9    4.360000e+06         Consumer
# 10   2.890000e+06       Technology
# 11   2.640000e+06       Technology
# 12  -2.200000e+06           Retail
# 13   2.180000e+06         Consumer
# 14   3.460000e+06       Technology
# 15   8.350000e+08           Retail
# 16   5.300000e+08           Retail
# 17   6.120000e+08           Retail
# 18   1.640000e+06  Food & Beverage
# 19   1.640000e+06  Food & Beverage
# 20   1.220000e+06      Real Estate
# 21   1.930000e+06      Real Estate
# 22   1.470000e+06    Entertainment
# 23   1.730000e+06  Food & Beverage
# 24   1.100000e+09       Technology
# 25   4.670000e+06           Energy
# 26   0.000000e+00          Finance
# 27   1.920000e+06         Consumer
# 28   3.590000e+06       Technology
# 29   1.840000e+10         Services
# ..            ...              ...
# 470  1.980000e+08      Diversified
# 471  4.730000e+08       Technology
# 472  5.720000e+08  Food & Beverage
# 473  7.990000e+07           Retail
# 474  2.510000e+08  Food & Beverage
# 475  5.070000e+08         Consumer
# 476  2.840000e+08          Finance
# 477  2.500000e+07       Industrial
# 478  5.400000e+08       Technology
# 479 -8.290000e+07  Food & Beverage
# 480  0.000000e+00      Real Estate
# 481 -2.350000e+08         Consumer
# 482  2.040000e+07      Diversified
# 483 -7.530000e+08      Real Estate
# 484  9.870000e+07      Health Care
# 485  5.290000e+08      Commodities
# 486  4.470000e+08           Retail
# 487  3.180000e+08         Consumer
# 488  3.180000e+08         Consumer
# 489  3.180000e+08         Consumer
# 490  3.180000e+08         Consumer
# 491  3.180000e+08         Consumer
# 492  1.000000e+08      Diversified
# 493 -1.390000e+08       Industrial
# 494  2.820000e+06      Real Estate
# 495  3.800000e+07       Industrial
# 496  3.790000e+08           Retail
# 497 -4.020000e+07          Finance
# 498  5.740000e+08       Technology
# 499  1.810000e+08       Industrial
#
# [500 rows x 2 columns]
