# %% [markdown]
# [Dataset: Commercial Bank Failures, 1934-Present](https://www.kaggle.com/fdic/bank-failures)

# %%
import pandas as pd

# %%
bank = pd.read_csv("/Users/AdamLiu/Code/Machine_Learning/Datasets/Kaggle/bank-failures.csv")

# %%
print(bank.columns.values)
# Out:
# ['Financial Institution Number' 'Institution Name' 'Institution Type'
#  'Charter Type' 'Headquarters' 'Failure Date' 'Insurance Fund'
#  'Certificate Number' 'Transaction Type' 'Total Deposits' 'Total Assets'
#  'Estimated Loss (2015)']

# %%
bank.loc[:, 'Headquarters'].value_counts()
# Out:
# HOUSTON, TX           76
# DALLAS, TX            47
# CHICAGO, IL           40
# SAN ANTONIO, TX       38
# LOS ANGELES, CA       34
# AUSTIN, TX            33
# NEW ORLEANS, LA       21
# DENVER, CO            21
# MIAMI, FL             20
# NEW YORK, NY          19
# OKLAHOMA CITY, OK     18
# PHOENIX, AZ           16
# BOSTON, MA            15
# ATLANTA, GA           15
# SAN DIEGO, CA         13
# PLANO, TX             13
# SCOTTSDALE, AZ        12
# SAN FRANCISCO, CA     12
# BATON ROUGE, LA       11
# ARLINGTON, TX         11
# FORT WORTH, TX        11
# TYLER, TX             10
# METAIRIE, LA           9
# ALBUQUERQUE, NM        9
# KANSAS CITY, MO        9
# SALT LAKE CITY, UT     9
# PHILADELPHIA, PA       9
# NEWPORT BEACH, CA      8
# RICHMOND, VA           8
# SHREVEPORT, LA         8
#                       ..
# VENTURA, CA            1
# TEMPLE, OK             1
# CHESTER, TX            1
# YUMA, CO               1
# LEAGUE CITY, TX        1
# FLAXTON, ND            1
# GORDON, TX             1
# BEREA, KY              1
# ROANOKE, IL            1
# ALGOMA, WI             1
# ELIZABTH, NJ           1
# CORVALLIS, OR          1
# DELPHI, IN             1
# TIMONIUM, MD           1
# LANHAM, MD             1
# AFTON, IA              1
# TALIHINA, OK           1
# NEWTOWN, MO            1
# LEO, IN                1
# STOVER, MO             1
# FLORENCE, IN           1
# SAGINAW, TX            1
# OAKLAND, MS            1
# FLAT ROCK, IL          1
# JERSEYVILLE, IL        1
# VIDALIA, LA            1
# MCCRACKEN, KS          1
# FERRIDAY, LA           1
# ASPEN, CO              1
# ANKENY, IA             1
# Name: Headquarters, dtype: int64

# %%
states = []
for city in list(bank.loc[:, 'Headquarters']):
    states.append(city.split(", ")[1])

# %%
states
# Out:
# ['PA',
#  'IL',
#  'MT',
#  'IN',
#  'KY',
#  'MN',
#  'WI',
#  'GA',
#  'WI',
#  'NJ',
#  'VA',
#  'SC',
#  'OK',
#  'OK',
#  'KS',
#  'GA',
#  'KS',
#  'MO',
#  'WI',
#  'WI',
#  'NE',
#  'GA',
#  'GA',
#  'OH',
#  'PA',
#  'TX',
#  'PA',
#  'TX',
#  'MI',
#  'WI',
#  'MO',
#  'WI',
#  'NJ',
#  'KY',
#  'TN',
#  'TN',
#  'OK',
#  'MO',
#  'MI',
#  'MI',
#  'MI',
#  'MS',
#  'IN',
#  'MO',
#  'MO',
#  'KY',
#  'MO',
#  'MO',
#  'SD',
#  'TX',
#  'KS',
#  'TN',
#  'TN',
#  'IN',
#  'IA',
#  'MS',
#  'TN',
#  'KY',
#  'SD',
#  'MO',
#  'TX',
#  'MO',
#  'MO',
#  'MO',
#  'MO',
#  'LA',
#  'IN',
#  'MO',
#  'MO',
#  'IL',
#  'NJ',
#  'KY',
#  'KS',
#  'MO',
#  'NJ',
#  'CT',
#  'MO',
#  'IN',
#  'MO',
#  'MO',
#  'MO',
#  'OK',
#  'MO',
#  'MO',
#  'LA',
#  'OH',
#  'WI',
#  'IN',
#  'IN',
#  'IN',
#  'KS',
#  'ND',
#  'SD',
#  'ND',
#  'ND',
#  'ND',
#  'ND',
#  'ND',
#  'ND',
#  'ND',
#  'ND',
#  'ND',
#  'TX',
#  'SD',
#  'ND',
#  'MO',
#  'SD',
#  'SD',
#  'MT',
#  'SD',
#  'IL',
#  'ND',
#  'TX',
#  'TX',
#  'TN',
#  'MO',
#  'SD',
#  'SD',
#  'MO',
#  'VA',
#  'IL',
#  'MO',
#  'PA',
#  'WI',
#  'IN',
#  'SD',
#  'TX',
#  'MI',
#  'MO',
#  'LA',
#  'KY',
#  'TX',
#  'KY',
#  'MO',
#  'KY',
#  'MO',
#  'GA',
#  'MT',
#  'TN',
#  'VA',
#  'IN',
#  'MO',
#  'MO',
#  'MO',
#  'AL',
#  'NY',
#  'WI',
#  'WV',
#  'IL',
#  'MA',
#  'MO',
#  'ND',
#  'NJ',
#  'TX',
#  'TX',
#  'NJ',
#  'NJ',
#  'NJ',
#  'MN',
#  'IL',
#  'IA',
#  'PA',
#  'NJ',
#  'ND',
#  'KY',
#  'ND',
#  'KY',
#  'ND',
#  'MO',
#  'IN',
#  'AR',
#  'IL',
#  'WI',
#  'ND',
#  'NC',
#  'MO',
#  'WI',
#  'NY',
#  'KY',
#  'AR',
#  'SD',
#  'WI',
#  'IL',
#  'MI',
#  'NC',
#  'SD',
#  'MO',
#  'NE',
#  'AR',
#  'CO',
#  'TN',
#  'MO',
#  'TX',
#  'MO',
#  'NE',
#  'AR',
#  'VA',
#  'IA',
#  'ND',
#  'IN',
#  'VA',
#  'NJ',
#  'NC',
#  'IL',
#  'ND',
#  'NJ',
#  'NJ',
#  'SD',
#  'ND',
#  'SD',
#  'WI',
#  'SD',
#  'WI',
#  'SD',
#  'IA',
#  'ND',
#  'WI',
#  'IA',
#  'KY',
#  'NC',
#  'MD',
#  'KY',
#  'SD',
#  'TN',
#  'MD',
#  'SD',
#  'VT',
#  'WI',
#  'SD',
#  'MO',
#  'TN',
#  'SD',
#  'SD',
#  'ND',
#  'MN',
#  'NY',
#  'ND',
#  'SD',
#  'KY',
#  'GA',
#  'WV',
#  'MO',
#  'MO',
#  'AL',
#  'ND',
#  'NY',
#  'MA',
#  'WI',
#  'PA',
#  'KY',
#  'MD',
#  'WI',
#  'WI',
#  'MN',
#  'TX',
#  'WI',
#  'TX',
#  'ND',
#  'MD',
#  'MO',
#  'TX',
#  'PA',
#  'NJ',
#  'NJ',
#  'NJ',
#  'NH',
#  'IN',
#  'IN',
#  'NJ',
#  'KY',
#  'FL',
#  'KY',
#  'WV',
#  'WI',
#  'NJ',
#  'ND',
#  'IN',
#  'WI',
#  'AR',
#  'OK',
#  'NJ',
#  'IL',
#  'NJ',
#  'NJ',
#  'TN',
#  'NJ',
#  'NY',
#  'NJ',
#  'TX',
#  'VA',
#  'WI',
#  'NJ',
#  'NJ',
#  'NJ',
#  'MT',
#  'NJ',
#  'CT',
#  'NJ',
#  'NJ',
#  'NJ',
#  'IL',
#  'IL',
#  'KY',
#  'WI',
#  'NE',
#  'NJ',
#  'KS',
#  'KY',
#  'NY',
#  'KS',
#  'TN',
#  'NJ',
#  'TX',
#  'MO',
#  'PA',
#  'NJ',
#  'NJ',
#  'NY',
#  'NY',
#  'VT',
#  'MO',
#  'NJ',
#  'KY',
#  'WA',
#  'PA',
#  'NY',
#  'NY',
#  'ND',
#  'ND',
#  'ND',
#  'KY',
#  'NY',
#  'NY',
#  'PA',
#  'IN',
#  'NY',
#  'OK',
#  'IN',
#  'NJ',
#  'NJ',
#  'WI',
#  'PA',
#  'WI',
#  'GA',
#  'NY',
#  'NY',
#  'SD',
#  'IA',
#  'NY',
#  'GA',
#  'MD',
#  'WI',
#  'KS',
#  'NY',
#  'CA',
#  'MO',
#  'OK',
#  'IL',
#  'MS',
#  'PA',
#  'NY',
#  'NY',
#  'KS',
#  'NY',
#  'NY',
#  'WI',
#  'NY',
#  'MI',
#  'PA',
#  'PA',
#  'PA',
#  'MN',
#  'KY',
#  'NC',
#  'NJ',
#  'NY',
#  'PA',
#  'NY',
#  'FL',
#  'PA',
#  'PA',
#  'WI',
#  'PA',
#  'PA',
#  'OR',
#  'PA',
#  'WI',
#  'PA',
#  'MO',
#  'PA',
#  'VT',
#  'NC',
#  'IL',
#  'NY',
#  'PA',
#  'IN',
#  'PA',
#  'VA',
#  'VA',
#  'WY',
#  'IL',
#  'PA',
#  'SC',
#  'WI',
#  'NJ',
#  'OK',
#  'TX',
#  'IN',
#  'MT',
#  'OH',
#  'IN',
#  'MI',
#  'NC',
#  'IL',
#  'PA',
#  'MO',
#  'PA',
#  'AL',
#  'IL',
#  'AR',
#  'PA',
#  'IL',
#  'GA',
#  'KY',
#  'TX',
#  'ID',
#  'ID',
#  'CA',
#  'ME',
#  'TX',
#  'NY',
#  'TX',
#  'OR',
#  'TX',
#  'OH',
#  'NJ',
#  'NE',
#  'MO',
#  'TX',
#  'OK',
#  'IA',
#  'OK',
#  'GA',
#  'OK',
#  'TX',
#  'PA',
#  'IL',
#  'IL',
#  'TX',
#  'MI',
#  'TX',
#  'MO',
#  'CA',
#  'VA',
#  'NE',
#  'CA',
#  'CO',
#  'TX',
#  'TX',
#  'TX',
#  'FL',
#  'AR',
#  'TX',
#  'CO',
#  'MO',
#  'MI',
#  'TX',
#  'AL',
#  'FL',
#  'TX',
#  'KS',
#  'TX',
#  'FL',
#  'OK',
#  'CO',
#  'TX',
#  'MI',
#  'TX',
#  'TX',
#  'IL',
#  'TX',
#  'TX',
#  'UT',
#  'IA',
#  'MI',
#  'KY',
#  'NJ',
#  'MO',
#  'PA',
#  'KY',
#  'TX',
#  'MI',
#  'IL',
#  'NE',
#  'CO',
#  'MO',
#  'MA',
#  'LA',
#  'CO',
#  'NE',
#  'TX',
#  'IA',
#  'CA',
#  'SC',
#  'MI',
#  'NY',
#  'IA',
#  'MO',
#  'OH',
#  'TX',
#  'MA',
#  'WI',
#  'MS',
#  'AR',
#  'IL',
#  'TX',
#  'WI',
#  'AZ',
#  'KS',
#  'NJ',
#  'CO',
#  'TN',
#  'TX',
#  'CA',
#  'TX',
#  'NJ',
#  'CO',
#  'KY',
#  'TX',
#  'MA',
#  'NY',
#  'GA',
#  'PA',
#  'TX',
#  'LA',
#  'OK',
#  'CT',
#  'GA',
#  'LA',
#  'IA',
#  'IL',
#  'AL',
#  'AL',
#  'AL',
#  'IL',
#  'GA',
#  'CO',
#  'AL',
#  'TN',
#  'IL',
#  'IL',
#  'KS',
#  'MS',
#  'NJ',
#  'TX',
#  'FL',
#  'ND',
#  'MA',
#  'KS',
#  'TN',
#  'KS',
#  'WV',
#  'IL',
#  'KS',
#  'AL',
#  'IL',
#  'IL',
#  'GA',
#  'IL',
#  'OR',
#  'NY',
#  'AZ',
#  'OR',
#  'CO',
#  'IL',
#  'FL',
#  'IL',
#  'TN',
#  'TX',
#  'IA',
#  'VA',
#  'TX',
#  'CA',
#  'TN',
#  'IL',
#  'MI',
#  'AR',
#  'IL',
#  'MO',
#  'OK',
#  'TX',
#  'TX',
#  'MA',
#  'IA',
#  'AR',
#  'IL',
#  'CA',
#  'TN',
#  'IL',
#  'AL',
#  'WV',
#  'TX',
#  'AR',
#  'KS',
#  'TX',
#  'MO',
#  'OK',
#  'CA',
#  'MO',
#  'IL',
#  'MN',
#  'IL',
#  'CA',
#  'CA',
#  'CA',
#  'NJ',
#  'OR',
#  'AR',
#  'OR',
#  'IL',
#  'CA',
#  'KY',
#  'IL',
#  'OR',
#  'TN',
#  'TN',
#  'TN',
#  'TN',
#  'CA',
#  'TN',
#  'TN',
#  'SD',
#  'WY',
#  'NV',
#  'NE',
#  'IL',
#  'TN',
#  'IL',
#  'TN',
#  'TX',
#  'IL',
#  'TN',
#  'TN',
#  'KS',
#  'TN',
#  'TX',
#  'CO',
#  'OR',
#  'TX',
#  'OH',
#  'NM',
#  'MT',
#  'IL',
#  'LA',
#  'AL',
#  'OK',
#  'TN',
#  'TN',
#  'VA',
#  'KS',
#  'WV',
#  'OR',
#  'IL',
#  'CA',
#  'TX',
#  'FL',
#  'OR',
#  'MI',
#  'TX',
#  'CA',
#  'TX',
#  'MS',
#  'TN',
#  'TN',
#  'TX',
#  'IN',
#  'KY',
#  'IL',
#  'CA',
#  'TN',
#  'WY',
#  'WY',
#  'MN',
#  'TX',
#  'CA',
#  'OK',
#  'MS',
#  'TN',
#  'LA',
#  'CA',
#  'IL',
#  'MN',
#  'CA',
#  'AL',
#  'OR',
#  'SD',
#  'AR',
#  'TN',
#  'MO',
#  'IA',
#  'TN',
#  'TX',
#  'IL',
#  'MN',
#  'TN',
#  'AR',
#  'IA',
#  'IN',
#  'TX',
#  'KS',
#  'CO',
#  'OR',
#  'NE',
#  'IA',
#  'OK',
#  'NE',
#  'FL',
#  'OK',
#  'OK',
#  'KS',
#  'MO',
#  'TN',
#  'OK',
#  'MN',
#  'NE',
#  'NE',
#  'KS',
#  'OR',
#  'TN',
#  'KS',
#  'TN',
#  'UT',
#  'CO',
#  'CA',
#  'KS',
#  'NE',
#  'KS',
#  'IL',
#  'WY',
#  'NE',
#  'OR',
#  'TX',
#  'OK',
#  'IA',
#  'TN',
#  'IA',
#  'OK',
#  'CA',
#  'TN',
#  'CO',
#  'MN',
#  'IA',
#  'FL',
#  'NE',
#  'CA',
#  'IA',
#  'IL',
#  'CA',
#  'CO',
#  'OK',
#  'CA',
#  'NE',
#  'CA',
#  'UT',
#  'OR',
#  'TX',
#  'CO',
#  'IA',
#  'CA',
#  'KS',
#  'IA',
#  'MO',
#  'IA',
#  'OK',
#  'TX',
#  'TX',
#  'NE',
#  'NE',
#  'NE',
#  'AR',
#  'NE',
#  'MN',
#  'TN',
#  'TN',
#  'WY',
#  'KS',
#  'MN',
#  'WI',
#  'KS',
#  'NY',
#  'OK',
#  'IA',
#  'LA',
#  'LA',
#  'LA',
#  'LA',
#  'LA',
#  'LA',
#  'TN',
#  'KS',
#  'AL',
#  'OK',
#  'TX',
#  'KS',
#  'FL',
#  'MO',
#  'CO',
#  'WY',
#  'KS',
#  'KS',
#  'KS',
#  'TX',
#  'NE',
#  'TX',
#  'MN',
#  'IA',
#  'OK',
#  'IL',
#  'CO',
#  'KS',
#  'TX',
#  'MT',
#  'CA',
#  'KS',
#  'LA',
#  'MO',
#  'MO',
#  'CA',
#  'NM',
#  'WA',
#  'TN',
#  'CO',
#  'TN',
#  'NM',
#  'NY',
#  'NE',
#  'KS',
#  'OK',
#  'TX',
#  'FL',
#  'OK',
#  'MO',
#  'WY',
#  'OK',
#  'CA',
#  'TX',
#  'MN',
#  'UT',
#  'OK',
#  'WY',
#  'IA',
#  'CO',
#  'TX',
#  'IA',
#  'TX',
#  'KS',
#  'MO',
#  'KS',
#  'OK',
#  'CA',
#  'TX',
#  'IN',
#  'MI',
#  'OR',
#  'OK',
#  'NE',
#  'OR',
#  'AR',
#  'NM',
#  'MO',
#  'MO',
#  'NE',
#  'NE',
#  'MO',
#  'NE',
#  'CA',
#  'MN',
#  'OK',
#  'KS',
#  'CA',
#  'LA',
#  'WY',
#  'LA',
#  'UT',
#  'UT',
#  'MO',
#  'IA',
#  'CA',
#  'NE',
#  'CA',
#  'TX',
#  'IA',
#  'FL',
#  'FL',
#  'CA',
#  'OK',
#  'WY',
#  'IA',
#  'TX',
#  'TX',
#  'NE',
#  'MO',
#  'MN',
#  'IA',
#  'WA',
#  'CA',
#  'SD',
#  'KS',
#  'TX',
#  'UT',
#  'MO',
#  'NM',
#  'IN',
#  'TX',
#  'LA',
#  'MO',
#  'IA',
#  'CA',
#  'CA',
#  'UT',
#  'FL',
#  'TN',
#  'TX',
#  'TX',
#  'OK',
#  'IA',
#  'KS',
#  'OK',
#  'ID',
#  'AL',
#  'KS',
#  'CA',
#  'CA',
#  'TX',
#  'FL',
#  'CO',
#  'NE',
#  'IA',
#  'OK',
#  'MT',
#  'CA',
#  'KS',
#  'WY',
#  'TX',
#  'LA',
#  'LA',
#  'TX',
#  'KS',
#  'WI',
#  'KY',
#  'KY',
#  'IA',
#  'CA',
#  'TX',
#  'TX',
#  'MN',
#  'OK',
#  'KS',
#  'NM',
#  'WY',
#  'MO',
#  'NE',
#  'TX',
#  'TN',
#  'KS',
#  'IA',
#  'IL',
#  'OH',
#  'CO',
#  'CO',
#  'OK',
#  'NE',
#  'IA',
#  'TX',
#  'KS',
#  'OK',
#  'IA',
#  'TX',
#  'WY',
#  'AK',
#  'OK',
#  'KS',
#  'IL',
#  'KS',
#  'TX',
#  'CO',
#  'FL',
#  'CO',
#  'WY',
#  'MO',
#  'OK',
#  'TX',
#  'OK',
#  'CA',
#  'TX',
#  'TX',
#  'TX',
#  'TX',
#  'KS',
#  'LA',
#  ...]

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim()

# %%
import pandas
import rpy2.robjects as robjects
from rpy2.robjects.packages import importr
from rpy2.robjects.lib import grid

# %%
from rpy2.robjects.lib import ggplot2
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:186: RRuntimeWarning: Error in dyn.load(file, DLLpath = DLLpath, ...) :
#   unable to load shared object '/Library/Frameworks/R.framework/Versions/3.3/Resources/library/lazyeval/libs/lazyeval.so':
#   dlopen(/Library/Frameworks/R.framework/Versions/3.3/Resources/library/lazyeval/libs/lazyeval.so, 6): Library not loaded: /Library/Frameworks/R.framework/Versions/3.2/Resources/lib/libR.dylib
#   Referenced from: /Library/Frameworks/R.framework/Versions/3.3/Resources/library/lazyeval/libs/lazyeval.so
#   Reason: image not found
#
#   warnings.warn(x, RRuntimeWarning)
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# <ipython-input-9-233955da1aba> in <module>()
# ----> 1 from rpy2.robjects.lib import ggplot2
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/rpy2/robjects/lib/ggplot2.py in <module>()
#      53 NULL = robjects.NULL
#      54
# ---> 55 ggplot2 = importr('ggplot2', on_conflict="warn")
#      56 ggplot2 = WeakPackage(ggplot2._env,
#      57                       ggplot2.__rname__,
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/rpy2/robjects/packages.py in importr(name, lib_loc, robject_translations, signature_translation, suppress_messages, on_conflict, symbol_r2python, symbol_check_after, data)
#     451     if _package_has_namespace(rname,
#     452                               _system_file(package = rname)):
# --> 453         env = _get_namespace(rname)
#     454         version = _get_namespace_version(rname)[0]
#     455         exported_names = set(_get_namespace_exports(rname))
#
# RRuntimeError: Error in dyn.load(file, DLLpath = DLLpath, ...) :
#   unable to load shared object '/Library/Frameworks/R.framework/Versions/3.3/Resources/library/lazyeval/libs/lazyeval.so':
#   dlopen(/Library/Frameworks/R.framework/Versions/3.3/Resources/library/lazyeval/libs/lazyeval.so, 6): Library not loaded: /Library/Frameworks/R.framework/Versions/3.2/Resources/lib/libR.dylib
#   Referenced from: /Library/Frameworks/R.framework/Versions/3.3/Resources/library/lazyeval/libs/lazyeval.so
#   Reason: image not found

# %%
## read in the distances to railroad (we calculated)
neardist = pandas.read_csv('data/NearDistance.csv')

## convert to R dataframe, via Python Dictionary data type
neardist_dataf = {'OBAMA_SHAR':  robjects.FloatVector(neardist['OBAMA_SHAR']), 'NEAR_DIST': robjects.FloatVector(neardist['NEAR_DIST'])}
RR_distance = robjects.DataFrame(neardist_dataf)
print RR_distance.colnames

## we use R instance of robjects to issue R commands
## load  pre-prepared IL map data sets and print contents:
robjects.r('print(load("data/IL.Rdata"))')

## loaded data sets can now be accessed through R handle
## note that different from R dot . is not valid for Python variable names!
IL_railroads = robjects.r('IL.railroads')
IL_final = robjects.r('IL.final')

## import device driver from R with importr to plot to PNG
## we can then call any function in the grdevices package
grdevices = importr('grDevices')
grdevices.png(file='mapplot.png', width=1300, height=1000)

## plot the map
## note that the order matters when we add another layer in ggplot (here IL_railroads): first aes, then data, that's different from R 
## (see http://permalink.gmane.org/gmane.comp.python.rpy/2349) 
## note that we use dictionary to set the opts to be able to set options as keywords, for example legend.key.size
p_map = ggplot2.ggplot(IL_final) + \
     ggplot2.geom_polygon(ggplot2.aes(x = 'long', y = 'lat', group = 'group', color = 'ObamaShare', fill = 'ObamaShare')) + \
     ggplot2.scale_fill_gradient(high = 'blue', low = 'red') + \
     ggplot2.scale_fill_continuous(name = "Obama Vote Share") + \
     ggplot2.scale_colour_continuous(name = "Obama Vote Share") + \
     ggplot2.opts(**{'legend.position': 'left', 'legend.key.size': robjects.r.unit(2, 'lines'), 'legend.title' : ggplot2.theme_text(size = 14, hjust=0), \
                     'legend.text': ggplot2.theme_text(size = 12), 'title' : "Obama Vote Share and Distance to Railroads in IL", \
                     'plot.title': ggplot2.theme_text(size = 24), 'plot.margin': robjects.r.unit(robjects.r.rep(0,4),'lines'), \
                     'panel.background': ggplot2.theme_blank(), 'panel.grid.minor': ggplot2.theme_blank(), 'panel.grid.major': ggplot2.theme_blank(), \
                     'axis.ticks': ggplot2.theme_blank(), 'axis.title.x': ggplot2.theme_blank(), 'axis.title.y': ggplot2.theme_blank(), \
                     'axis.title.x': ggplot2.theme_blank(), 'axis.title.x': ggplot2.theme_blank(), 'axis.text.x': ggplot2.theme_blank(), \
                     'axis.text.y': ggplot2.theme_blank()} ) + \
     ggplot2.geom_line(ggplot2.aes(x='long', y='lat', group='group'), data=IL_railroads, color='grey', size=0.2) + \
     ggplot2.coord_equal()

p_map.plot()

## add the scatterplot
## define layout of subplot with viewports
vp_sub = grid.viewport(x = 0.19, y = 0.2, width = 0.32, height = 0.4)

p_sub = ggplot2.ggplot(RR_distance) + \
    ggplot2.aes_string(x = 'OBAMA_SHAR', y= 'NEAR_DIST') + \
    ggplot2.geom_point(ggplot2.aes(color='OBAMA_SHAR')) + \
    ggplot2.stat_smooth(color="black") + \
    ggplot2.opts(**{'legend.position': 'none'}) + \
    ggplot2.scale_x_continuous("Obama Vote Share") + \
    ggplot2.scale_y_continuous("Distance to nearest Railroad")

p_sub.plot(vp=vp_sub)

grdevices.dev_off()
