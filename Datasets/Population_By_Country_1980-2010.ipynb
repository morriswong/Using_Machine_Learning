# %%
import pandas as pd

# %%
dataset_loc = "/Users/AdamLiu/Code/Machine_Learning/Datasets/Others/energy_info_admin/populationbycountry19802010millions.csv"
population = pd.read_csv(dataset_loc, index_col = 0)

# %%
for i in population.columns.values:
    print(i)
    population[i] = pd.to_numeric(population[i])
population.head(10)
# Out:
#                                 1980       1981       1982       1983  \
# North America              320.27638  324.44694  328.62014  332.72487
# Bermuda                      0.05473    0.05491    0.05517    0.05551
# Canada                      24.59330   24.90000   25.20190   25.45630
# Greenland                    0.05021    0.05103    0.05166    0.05211
# Mexico                      68.34748   69.96926   71.64090   73.36288
# Saint Pierre and Miquelon    0.00599    0.00601    0.00605    0.00607
# United States              227.22468  229.46571  231.66446  233.79199
# Central & South America    293.05856  299.43033  305.95253  312.51136
# Antarctica                       NaN        NaN        NaN        NaN
# Antigua and Barbuda          0.06855    0.06826    0.06801    0.06562
#
#                                 1984       1985       1986       1987  \
# North America              336.72143  340.74811  344.89548  349.07829
# ...

# %%
population.get_value("North America", "1980")
# Out:
# 320.27637999999996
